# %%
import os

# %%
PATH = '/Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/'
subject_nii=os.listdir(PATH)
subject_list=[x.split('.')[0] for x in subject_nii]

print(subject_nii)
print(subject_list)
# Out:
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/aa1.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/ap4.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/aq0.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/ar1.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/ar2.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/au8.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/av9.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/aw5.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/ax9.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/az7.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/bc8.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/bf1.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/bf7.nii
# /Users/pruthvi_local/Desktop/Lesion_Segmentation/Only_NIIs/bg1.nii
# ...

# %%
from msct_image import Image
from sct_deepseg_lesion import crop_image_around_centerline

# %%
for subject in subject_list:
    img_path = PATH + subject + '.nii'
    cmd_sct ='sct_get_centerline -i ' + img_path + ' -c t2 -ofolder ' + '/Users/pruthvi_local/Desktop/Lesion_Segmentation/01_preprocess/'
    os.system(cmd_sct)

# %%
for subject in subject_list:
    img_path = PATH + subject + '.nii'
    ctr_path = '/Users/pruthvi_local/Desktop/Lesion_Segmentation/01_preprocess/' + subject + '_centerline_optic.nii'
    img_out_path = data_folder + subject + '_crop.nii'
    crop_image_around_centerline(img_path, ctr_path, out_path, 48)
